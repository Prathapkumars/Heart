# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
#Let's start with importing necessary libraries
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.model_selection import KFold
from statsmodels.stats.outliers_influence import variance_inflation_factor 
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data = pd.read_csv("heart.csv") # Reading the Data
data.head(20)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63    1   3       145   233    1        0      150      0      2.3
# 1    37    1   2       130   250    0        1      187      0      3.5
# 2    41    0   1       130   204    0        0      172      0      1.4
# 3    56    1   1       120   236    0        1      178      0      0.8
# 4    57    0   0       120   354    0        1      163      1      0.6
# 5    57    1   0       140   192    0        1      148      0      0.4
# 6    56    0   1       140   294    0        0      153      0      1.3
# 7    44    1   1       120   263    0        1      173      0      0.0
# 8    52    1   2       172   199    1        1      162      0      0.5
# 9    57    1   2       150   168    0        1      174      0      1.6
# 10   54    1   0       140   239    0        1      160      0      1.2
# 11   48    0   2       130   275    0        1      139      0      0.2
# 12   49    1   1       130   266    0        1      171      0      0.6
# 13   64    1   3       110   211    0        0      144      1      1.8
# 14   58    0   3       150   283    1        0      162      0      1.0
# 15   50    0   2       120   219    0        1      158      0      1.6
# 16   58    0   2       120   340    0        1      172      0      0.0
# 17   66    0   3       150   226    0        1      114      0      2.6
# 18   43    1   0       150   247    0        1      171      0      1.5
# 19   69    0   3       140   239    0        1      151      0      1.8
#
#     slope  ca  thal  target
# 0       0   0     1       1
# 1       0   0     2       1
# 2       2   0     2       1
# 3       2   0     2       1
# 4       2   0     2       1
# 5       1   0     1       1
# 6       1   0     2       1
# 7       2   0     3       1
# 8       2   0     3       1
# 9       2   0     2       1
# 10      2   0     2       1
# 11      2   0     2       1
# 12      2   0     2       1
# 13      1   0     2       1
# 14      2   0     2       1
# 15      1   0     2       1
# 16      2   0     2       1
# 17      0   0     2       1
# 18      2   0     2       1
# 19      2   2     2       1

# %%
data.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
data.shape
# Out:
# (303, 14)

# %%
data.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in data:
    if plotnumber<=16 :
        ax = plt.subplot(4,4,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.boxplot(data=data, width= 0.5,ax=ax,  fliersize=3)

# %%
X = data.drop(columns = ['target'])
y = data['target']

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in X:
    if plotnumber<=16 :
        ax = plt.subplot(4,4,plotnumber)
        sns.stripplot(y,X[column])
    plotnumber+=1
plt.show()

# %%
scalar = StandardScaler()
X_scaled = scalar.fit_transform(X)

# %%
vif = pd.DataFrame()
vif["vif"] = [variance_inflation_factor(X_scaled,i) for i in range(X_scaled.shape[1])]
vif["Features"] = X.columns

#let's check the values
vif
# Out:
#          vif  Features
# 0   1.443474       age
# 1   1.161866       sex
# 2   1.284456        cp
# 3   1.170591  trestbps
# 4   1.150174      chol
# 5   1.087379       fbs
# 6   1.060998   restecg
# 7   1.613726   thalach
# 8   1.402001     exang
# 9   1.705857   oldpeak
# 10  1.642595     slope
# 11  1.202570        ca
# 12  1.147279      thal

# %%
x_train,x_test,y_train,y_test = train_test_split(X_scaled,y, test_size= 0.25)

# %%
knn = KNeighborsClassifier()
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
y_pred = knn.predict(x_test)

# %%
knn.score(x_train,y_train)
# Out:
# 0.8854625550660793

# %%
print("The accuracy score is : ", accuracy_score(y_test,y_pred))
# Out:
# The accuracy score is :  0.8026315789473685

# %%
param_grid = { 'algorithm' : ['ball_tree', 'kd_tree', 'brute'],
               'leaf_size' : [18,19,20,25,27,30,32,34],
               'n_neighbors' : [3,5,7,9,10,11,12,13]
              }

# %%
gridsearch = GridSearchCV(knn, param_grid,verbose=3)

# %%
gridsearch.fit(x_train,y_train)
# Out:
# D:\anaconda\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# Fitting 3 folds for each of 192 candidates, totalling 576 fits
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=3, score=0.766, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=3, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=3, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=5, score=0.792, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=5, score=0.813, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=5, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=7, score=0.857, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=7, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=7, score=0.747, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=9, score=0.857, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=9, score=0.867, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=9, score=0.760, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=10, score=0.870, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=10, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=10, score=0.773, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=11, score=0.805, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=11, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=11, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=12, score=0.857, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=12, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=12, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=13, score=0.831, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=13, score=0.880, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=13, score=0.813, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=19, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=19, n_neighbors=3, score=0.766, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=19, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=19, n_neighbors=3, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=19, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=19, n_neighbors=3, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=19, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=19, n_neighbors=5, score=0.792, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=19, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=19, n_neighbors=5, score=0.813, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=19, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=19, n_neighbors=5, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=19, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=19, n_neighbors=7, score=0.857, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=19, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=19, n_neighbors=7, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=19, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=19, n_neighbors=7, score=0.747, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=19, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=19, n_neighbors=9, score=0.857, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=19, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=19, n_neighbors=9, score=0.867, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=19, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=19, n_neighbors=9, score=0.760, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=19, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=19, n_neighbors=10, score=0.870, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=19, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=19, n_neighbors=10, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=19, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=19, n_neighbors=10, score=0.773, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=19, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=19, n_neighbors=11, score=0.805, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=19, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=19, n_neighbors=11, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=19, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=19, n_neighbors=11, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=19, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=19, n_neighbors=12, score=0.857, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=19, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=19, n_neighbors=12, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=19, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=19, n_neighbors=12, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=19, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=19, n_neighbors=13, score=0.831, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=19, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=19, n_neighbors=13, score=0.880, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=19, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=19, n_neighbors=13, score=0.813, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=3, score=0.766, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=3, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=3, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=5, score=0.792, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=5, score=0.813, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=5, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=7, score=0.857, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=7, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=7, score=0.747, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=9, score=0.857, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=9, score=0.867, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=9, score=0.760, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=10, score=0.870, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=10, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=10, score=0.773, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=11, score=0.805, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=11, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=11, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=12, score=0.857, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=12, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=12, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=13, score=0.831, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=13, score=0.880, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=20, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=20, n_neighbors=13, score=0.813, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=3, score=0.766, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=3, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=3, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=5, score=0.792, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=5, score=0.813, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=5, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=7, score=0.857, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=7, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=7, score=0.747, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=9, score=0.857, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=9, score=0.867, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=9, score=0.760, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=10, score=0.870, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=10, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=10, score=0.773, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=11, score=0.805, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=11, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=11, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=12, score=0.857, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=12, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=12, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=13, score=0.831, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=13, score=0.880, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=25, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=25, n_neighbors=13, score=0.813, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=3, score=0.766, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=3, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=3, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=5, score=0.792, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=5, score=0.813, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=5, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=7, score=0.857, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=7, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=7, score=0.747, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=9, score=0.857, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=9, score=0.867, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=9, score=0.760, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=10, score=0.870, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=10, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=10, score=0.773, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=11, score=0.805, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=11, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=11, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=12, score=0.857, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=12, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=12, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=13, score=0.831, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=13, score=0.880, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=27, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=27, n_neighbors=13, score=0.813, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=3, score=0.766, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=3, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=3, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=5, score=0.792, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=5, score=0.813, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=5, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=7, score=0.857, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=7, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=7, score=0.747, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=9, score=0.857, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=9, score=0.867, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=9, score=0.760, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=10, score=0.870, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=10, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=10, score=0.773, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=11, score=0.805, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=11, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=11, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=12, score=0.857, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=12, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=12, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=13, score=0.831, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=13, score=0.880, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=30, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=30, n_neighbors=13, score=0.813, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=3, score=0.766, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=3, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=3, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=5, score=0.792, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=5, score=0.813, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=5, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=7, score=0.857, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=7, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=7, score=0.747, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=9, score=0.857, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=9, score=0.867, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=9, score=0.760, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=10, score=0.870, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=10, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=10, score=0.773, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=11, score=0.805, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=11, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=11, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=12, score=0.857, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=12, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=12, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=13, score=0.831, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=13, score=0.880, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=32, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=32, n_neighbors=13, score=0.813, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=3, score=0.766, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=3, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=3, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=5, score=0.792, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=5, score=0.813, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=5 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=5, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=7, score=0.857, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=7, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=7 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=7, score=0.747, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=9, score=0.857, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=9, score=0.867, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=9 ................
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=9, score=0.760, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=10, score=0.870, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=10, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=10 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=10, score=0.773, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=11, score=0.805, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=11, score=0.840, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=11 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=11, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=12, score=0.857, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=12, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=12 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=12, score=0.787, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=13, score=0.831, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=13, score=0.880, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=34, n_neighbors=13 ...............
# [CV]  algorithm=ball_tree, leaf_size=34, n_neighbors=13, score=0.813, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=3 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=3, score=0.766, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=3 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=3, score=0.840, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=3 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=3, score=0.787, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=5 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=5, score=0.792, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=5 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=5, score=0.813, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=5 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=5, score=0.787, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=7 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=7, score=0.857, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=7 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=7, score=0.840, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=7 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=7, score=0.747, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=9 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=9, score=0.857, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=9 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=9, score=0.867, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=9 ..................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=9, score=0.760, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=10 .................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=10, score=0.870, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=10 .................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=10, score=0.840, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=10 .................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=10, score=0.773, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=11 .................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=11, score=0.805, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=11 .................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=11, score=0.840, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=11 .................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=11, score=0.787, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=12 .................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=12, score=0.857, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=12 .................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=12, score=0.787, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=12 .................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=12, score=0.787, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=13 .................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=13, score=0.831, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=13 .................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=13, score=0.880, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=18, n_neighbors=13 .................
# [CV]  algorithm=kd_tree, leaf_size=18, n_neighbors=13, score=0.813, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=19, n_neighbors=3 ..................
# [CV]  algorithm=kd_tree, leaf_size=19, n_neighbors=3, score=0.766, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=19, n_neighbors=3 ..................
# [CV]  algorithm=kd_tree, leaf_size=19, n_neighbors=3, score=0.840, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=19, n_neighbors=3 ..................
# [CV]  algorithm=kd_tree, leaf_size=19, n_neighbors=3, score=0.787, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=19, n_neighbors=5 ..................
# [CV]  algorithm=kd_tree, leaf_size=19, n_neighbors=5, score=0.792, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=19, n_neighbors=5 ..................
# [CV]  algorithm=kd_tree, leaf_size=19, n_neighbors=5, score=0.813, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=19, n_neighbors=5 ..................
# [CV]  algorithm=kd_tree, leaf_size=19, n_neighbors=5, score=0.787, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=19, n_neighbors=7 ..................
# [CV]  algorithm=kd_tree, leaf_size=19, n_neighbors=7, score=0.857, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=19, n_neighbors=7 ..................
# [CV]  algorithm=kd_tree, leaf_size=19, n_neighbors=7, score=0.840, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=19, n_neighbors=7 ..................
# [CV]  algorithm=kd_tree, leaf_size=19, n_neighbors=7, score=0.747, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=19, n_neighbors=9 ..................
# [CV]  algorithm=kd_tree, leaf_size=19, n_neighbors=9, score=0.857, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=19, n_neighbors=9 ..................
# [CV]  algorithm=kd_tree, leaf_size=19, n_neighbors=9, score=0.867, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=19, n_neighbors=9 ..................
# [CV]  algorithm=kd_tree, leaf_size=19, n_neighbors=9, score=0.760, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=19, n_neighbors=10 .................
# [CV]  algorithm=kd_tree, leaf_size=19, n_neighbors=10, score=0.870, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=19, n_neighbors=10 .................
# [CV]  algorithm=kd_tree, leaf_size=19, n_neighbors=10, score=0.840, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=19, n_neighbors=10 .................
# [CV]  algorithm=kd_tree, leaf_size=19, n_neighbors=10, score=0.773, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=19, n_neighbors=11 .................
# [CV]  algorithm=kd_tree, leaf_size=19, n_neighbors=11, score=0.805, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=19, n_neighbors=11 .................
# [CV]  algorithm=kd_tree, leaf_size=19, n_neighbors=11, score=0.840, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=19, n_neighbors=11 .................
# [CV]  algorithm=kd_tree, leaf_size=19, n_neighbors=11, score=0.787, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=19, n_neighbors=12 .................
# [CV]  algorithm=kd_tree, leaf_size=19, n_neighbors=12, score=0.857, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=19, n_neighbors=12 .................
# [CV]  algorithm=kd_tree, leaf_size=19, n_neighbors=12, score=0.787, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=19, n_neighbors=12 .................
# [CV]  algorithm=kd_tree, leaf_size=19, n_neighbors=12, score=0.787, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=19, n_neighbors=13 .................
# [CV]  algorithm=kd_tree, leaf_size=19, n_neighbors=13, score=0.831, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=19, n_neighbors=13 .................
# [CV]  algorithm=kd_tree, leaf_size=19, n_neighbors=13, score=0.880, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=19, n_neighbors=13 .................
# [CV]  algorithm=kd_tree, leaf_size=19, n_neighbors=13, score=0.813, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=20, n_neighbors=3 ..................
# [CV]  algorithm=kd_tree, leaf_size=20, n_neighbors=3, score=0.766, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=20, n_neighbors=3 ..................
# [CV]  algorithm=kd_tree, leaf_size=20, n_neighbors=3, score=0.840, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=20, n_neighbors=3 ..................
# [CV]  algorithm=kd_tree, leaf_size=20, n_neighbors=3, score=0.787, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=20, n_neighbors=5 ..................
# [CV]  algorithm=kd_tree, leaf_size=20, n_neighbors=5, score=0.792, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=20, n_neighbors=5 ..................
# [CV]  algorithm=kd_tree, leaf_size=20, n_neighbors=5, score=0.813, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=20, n_neighbors=5 ..................
# [CV]  algorithm=kd_tree, leaf_size=20, n_neighbors=5, score=0.787, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=20, n_neighbors=7 ..................
# [CV]  algorithm=kd_tree, leaf_size=20, n_neighbors=7, score=0.857, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=20, n_neighbors=7 ..................
# [CV]  algorithm=kd_tree, leaf_size=20, n_neighbors=7, score=0.840, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=20, n_neighbors=7 ..................
# [CV]  algorithm=kd_tree, leaf_size=20, n_neighbors=7, score=0.747, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=20, n_neighbors=9 ..................
# [CV]  algorithm=kd_tree, leaf_size=20, n_neighbors=9, score=0.857, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=20, n_neighbors=9 ..................
# [CV]  algorithm=kd_tree, leaf_size=20, n_neighbors=9, score=0.867, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=20, n_neighbors=9 ..................
# [CV]  algorithm=kd_tree, leaf_size=20, n_neighbors=9, score=0.760, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=20, n_neighbors=10 .................
# [CV]  algorithm=kd_tree, leaf_size=20, n_neighbors=10, score=0.870, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=20, n_neighbors=10 .................
# [CV]  algorithm=kd_tree, leaf_size=20, n_neighbors=10, score=0.840, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=20, n_neighbors=10 .................
# [CV]  algorithm=kd_tree, leaf_size=20, n_neighbors=10, score=0.773, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=20, n_neighbors=11 .................
# [CV]  algorithm=kd_tree, leaf_size=20, n_neighbors=11, score=0.805, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=20, n_neighbors=11 .................
# [CV]  algorithm=kd_tree, leaf_size=20, n_neighbors=11, score=0.840, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=20, n_neighbors=11 .................
# [CV]  algorithm=kd_tree, leaf_size=20, n_neighbors=11, score=0.787, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=20, n_neighbors=12 .................
# [CV]  algorithm=kd_tree, leaf_size=20, n_neighbors=12, score=0.857, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=20, n_neighbors=12 .................
# [CV]  algorithm=kd_tree, leaf_size=20, n_neighbors=12, score=0.787, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=20, n_neighbors=12 .................
# [CV]  algorithm=kd_tree, leaf_size=20, n_neighbors=12, score=0.787, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=20, n_neighbors=13 .................
# [CV]  algorithm=kd_tree, leaf_size=20, n_neighbors=13, score=0.831, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=20, n_neighbors=13 .................
# [CV]  algorithm=kd_tree, leaf_size=20, n_neighbors=13, score=0.880, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=20, n_neighbors=13 .................
# [CV]  algorithm=kd_tree, leaf_size=20, n_neighbors=13, score=0.813, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=25, n_neighbors=3 ..................
# [CV]  algorithm=kd_tree, leaf_size=25, n_neighbors=3, score=0.766, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=25, n_neighbors=3 ..................
# [CV]  algorithm=kd_tree, leaf_size=25, n_neighbors=3, score=0.840, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=25, n_neighbors=3 ..................
# [CV]  algorithm=kd_tree, leaf_size=25, n_neighbors=3, score=0.787, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=25, n_neighbors=5 ..................
# [CV]  algorithm=kd_tree, leaf_size=25, n_neighbors=5, score=0.792, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=25, n_neighbors=5 ..................
# [CV]  algorithm=kd_tree, leaf_size=25, n_neighbors=5, score=0.813, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=25, n_neighbors=5 ..................
# [CV]  algorithm=kd_tree, leaf_size=25, n_neighbors=5, score=0.787, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=25, n_neighbors=7 ..................
# [CV]  algorithm=kd_tree, leaf_size=25, n_neighbors=7, score=0.857, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=25, n_neighbors=7 ..................
# [CV]  algorithm=kd_tree, leaf_size=25, n_neighbors=7, score=0.840, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=25, n_neighbors=7 ..................
# [CV]  algorithm=kd_tree, leaf_size=25, n_neighbors=7, score=0.747, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=25, n_neighbors=9 ..................
# [CV]  algorithm=kd_tree, leaf_size=25, n_neighbors=9, score=0.857, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=25, n_neighbors=9 ..................
# [CV]  algorithm=kd_tree, leaf_size=25, n_neighbors=9, score=0.867, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=25, n_neighbors=9 ..................
# [CV]  algorithm=kd_tree, leaf_size=25, n_neighbors=9, score=0.760, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=25, n_neighbors=10 .................
# [CV]  algorithm=kd_tree, leaf_size=25, n_neighbors=10, score=0.870, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=25, n_neighbors=10 .................
# [CV]  algorithm=kd_tree, leaf_size=25, n_neighbors=10, score=0.840, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=25, n_neighbors=10 .................
# [CV]  algorithm=kd_tree, leaf_size=25, n_neighbors=10, score=0.773, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=25, n_neighbors=11 .................
# [CV]  algorithm=kd_tree, leaf_size=25, n_neighbors=11, score=0.805, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=25, n_neighbors=11 .................
# [CV]  algorithm=kd_tree, leaf_size=25, n_neighbors=11, score=0.840, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=25, n_neighbors=11 .................
# [CV]  algorithm=kd_tree, leaf_size=25, n_neighbors=11, score=0.787, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=25, n_neighbors=12 .................
# [CV]  algorithm=kd_tree, leaf_size=25, n_neighbors=12, score=0.857, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=25, n_neighbors=12 .................
# [CV]  algorithm=kd_tree, leaf_size=25, n_neighbors=12, score=0.787, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=25, n_neighbors=12 .................
# [CV]  algorithm=kd_tree, leaf_size=25, n_neighbors=12, score=0.787, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=25, n_neighbors=13 .................
# [CV]  algorithm=kd_tree, leaf_size=25, n_neighbors=13, score=0.831, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=25, n_neighbors=13 .................
# [CV]  algorithm=kd_tree, leaf_size=25, n_neighbors=13, score=0.880, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=25, n_neighbors=13 .................
# [CV]  algorithm=kd_tree, leaf_size=25, n_neighbors=13, score=0.813, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=27, n_neighbors=3 ..................
# [CV]  algorithm=kd_tree, leaf_size=27, n_neighbors=3, score=0.766, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=27, n_neighbors=3 ..................
# [CV]  algorithm=kd_tree, leaf_size=27, n_neighbors=3, score=0.840, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=27, n_neighbors=3 ..................
# [CV]  algorithm=kd_tree, leaf_size=27, n_neighbors=3, score=0.787, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=27, n_neighbors=5 ..................
# [CV]  algorithm=kd_tree, leaf_size=27, n_neighbors=5, score=0.792, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=27, n_neighbors=5 ..................
# [CV]  algorithm=kd_tree, leaf_size=27, n_neighbors=5, score=0.813, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=27, n_neighbors=5 ..................
# [CV]  algorithm=kd_tree, leaf_size=27, n_neighbors=5, score=0.787, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=27, n_neighbors=7 ..................
# [CV]  algorithm=kd_tree, leaf_size=27, n_neighbors=7, score=0.857, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=27, n_neighbors=7 ..................
# [CV]  algorithm=kd_tree, leaf_size=27, n_neighbors=7, score=0.840, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=27, n_neighbors=7 ..................
# [CV]  algorithm=kd_tree, leaf_size=27, n_neighbors=7, score=0.747, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=27, n_neighbors=9 ..................
# [CV]  algorithm=kd_tree, leaf_size=27, n_neighbors=9, score=0.857, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=27, n_neighbors=9 ..................
# [CV]  algorithm=kd_tree, leaf_size=27, n_neighbors=9, score=0.867, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=27, n_neighbors=9 ..................
# [CV]  algorithm=kd_tree, leaf_size=27, n_neighbors=9, score=0.760, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=27, n_neighbors=10 .................
# [CV]  algorithm=kd_tree, leaf_size=27, n_neighbors=10, score=0.870, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=27, n_neighbors=10 .................
# [CV]  algorithm=kd_tree, leaf_size=27, n_neighbors=10, score=0.840, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=27, n_neighbors=10 .................
# [CV]  algorithm=kd_tree, leaf_size=27, n_neighbors=10, score=0.773, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=27, n_neighbors=11 .................
# [CV]  algorithm=kd_tree, leaf_size=27, n_neighbors=11, score=0.805, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=27, n_neighbors=11 .................
# [CV]  algorithm=kd_tree, leaf_size=27, n_neighbors=11, score=0.840, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=27, n_neighbors=11 .................
# [CV]  algorithm=kd_tree, leaf_size=27, n_neighbors=11, score=0.787, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=27, n_neighbors=12 .................
# [CV]  algorithm=kd_tree, leaf_size=27, n_neighbors=12, score=0.857, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=27, n_neighbors=12 .................
# [CV]  algorithm=kd_tree, leaf_size=27, n_neighbors=12, score=0.787, total=   0.0s
# [CV] algorithm=kd_tree, leaf_size=27, n_neighbors=12 .................
# ...
# [CV]  algorithm=brute, leaf_size=25, n_neighbors=13, score=0.831, total=   0.1s
# [CV] algorithm=brute, leaf_size=25, n_neighbors=13 ...................
# [CV]  algorithm=brute, leaf_size=25, n_neighbors=13, score=0.880, total=   0.1s
# [CV] algorithm=brute, leaf_size=25, n_neighbors=13 ...................
# [CV]  algorithm=brute, leaf_size=25, n_neighbors=13, score=0.813, total=   0.1s
# [CV] algorithm=brute, leaf_size=27, n_neighbors=3 ....................
# [CV]  algorithm=brute, leaf_size=27, n_neighbors=3, score=0.766, total=   0.0s
# [CV] algorithm=brute, leaf_size=27, n_neighbors=3 ....................
# [CV]  algorithm=brute, leaf_size=27, n_neighbors=3, score=0.840, total=   0.2s
# [CV] algorithm=brute, leaf_size=27, n_neighbors=3 ....................
# [CV]  algorithm=brute, leaf_size=27, n_neighbors=3, score=0.787, total=   0.1s
# [CV] algorithm=brute, leaf_size=27, n_neighbors=5 ....................
# [CV]  algorithm=brute, leaf_size=27, n_neighbors=5, score=0.792, total=   0.2s
# [CV] algorithm=brute, leaf_size=27, n_neighbors=5 ....................
# [CV]  algorithm=brute, leaf_size=27, n_neighbors=5, score=0.813, total=   0.1s
# [CV] algorithm=brute, leaf_size=27, n_neighbors=5 ....................
# [CV]  algorithm=brute, leaf_size=27, n_neighbors=5, score=0.787, total=   0.1s
# [CV] algorithm=brute, leaf_size=27, n_neighbors=7 ....................
# [CV]  algorithm=brute, leaf_size=27, n_neighbors=7, score=0.857, total=   0.1s
# [CV] algorithm=brute, leaf_size=27, n_neighbors=7 ....................
# [CV]  algorithm=brute, leaf_size=27, n_neighbors=7, score=0.840, total=   0.1s
# [CV] algorithm=brute, leaf_size=27, n_neighbors=7 ....................
# [CV]  algorithm=brute, leaf_size=27, n_neighbors=7, score=0.747, total=   0.1s
# [CV] algorithm=brute, leaf_size=27, n_neighbors=9 ....................
# [CV]  algorithm=brute, leaf_size=27, n_neighbors=9, score=0.857, total=   0.1s
# [CV] algorithm=brute, leaf_size=27, n_neighbors=9 ....................
# [CV]  algorithm=brute, leaf_size=27, n_neighbors=9, score=0.867, total=   0.1s
# [CV] algorithm=brute, leaf_size=27, n_neighbors=9 ....................
# [CV]  algorithm=brute, leaf_size=27, n_neighbors=9, score=0.760, total=   0.1s
# [CV] algorithm=brute, leaf_size=27, n_neighbors=10 ...................
# [CV]  algorithm=brute, leaf_size=27, n_neighbors=10, score=0.870, total=   0.1s
# [CV] algorithm=brute, leaf_size=27, n_neighbors=10 ...................
# [CV]  algorithm=brute, leaf_size=27, n_neighbors=10, score=0.840, total=   0.1s
# [CV] algorithm=brute, leaf_size=27, n_neighbors=10 ...................
# [CV]  algorithm=brute, leaf_size=27, n_neighbors=10, score=0.773, total=   0.1s
# [CV] algorithm=brute, leaf_size=27, n_neighbors=11 ...................
# [CV]  algorithm=brute, leaf_size=27, n_neighbors=11, score=0.805, total=   0.1s
# [CV] algorithm=brute, leaf_size=27, n_neighbors=11 ...................
# [CV]  algorithm=brute, leaf_size=27, n_neighbors=11, score=0.840, total=   0.1s
# [CV] algorithm=brute, leaf_size=27, n_neighbors=11 ...................
# [CV]  algorithm=brute, leaf_size=27, n_neighbors=11, score=0.787, total=   0.3s
# [CV] algorithm=brute, leaf_size=27, n_neighbors=12 ...................
# [CV]  algorithm=brute, leaf_size=27, n_neighbors=12, score=0.857, total=   0.2s
# [CV] algorithm=brute, leaf_size=27, n_neighbors=12 ...................
# [CV]  algorithm=brute, leaf_size=27, n_neighbors=12, score=0.787, total=   0.1s
# [CV] algorithm=brute, leaf_size=27, n_neighbors=12 ...................
# [CV]  algorithm=brute, leaf_size=27, n_neighbors=12, score=0.787, total=   0.1s
# [CV] algorithm=brute, leaf_size=27, n_neighbors=13 ...................
# [CV]  algorithm=brute, leaf_size=27, n_neighbors=13, score=0.831, total=   0.3s
# [CV] algorithm=brute, leaf_size=27, n_neighbors=13 ...................
# [CV]  algorithm=brute, leaf_size=27, n_neighbors=13, score=0.880, total=   0.3s
# [CV] algorithm=brute, leaf_size=27, n_neighbors=13 ...................
# [CV]  algorithm=brute, leaf_size=27, n_neighbors=13, score=0.813, total=   0.3s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=3 ....................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=3, score=0.766, total=   0.1s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=3 ....................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=3, score=0.840, total=   0.3s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=3 ....................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=3, score=0.787, total=   0.3s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=5 ....................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=5, score=0.792, total=   0.1s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=5 ....................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=5, score=0.813, total=   0.2s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=5 ....................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=5, score=0.787, total=   0.1s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=7 ....................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=7, score=0.857, total=   0.3s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=7 ....................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=7, score=0.840, total=   0.0s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=7 ....................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=7, score=0.747, total=   0.2s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=9 ....................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=9, score=0.857, total=   0.0s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=9 ....................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=9, score=0.867, total=   0.3s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=9 ....................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=9, score=0.760, total=   0.0s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=10 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=10, score=0.870, total=   0.3s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=10 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=10, score=0.840, total=   0.3s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=10 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=10, score=0.773, total=   0.1s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=11 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=11, score=0.805, total=   0.3s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=11 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=11, score=0.840, total=   0.2s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=11 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=11, score=0.787, total=   0.1s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=12 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=12, score=0.857, total=   0.5s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=12 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=12, score=0.787, total=   0.0s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=12 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=12, score=0.787, total=   0.1s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=13 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=13, score=0.831, total=   0.0s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=13 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=13, score=0.880, total=   0.1s
# [CV] algorithm=brute, leaf_size=30, n_neighbors=13 ...................
# [CV]  algorithm=brute, leaf_size=30, n_neighbors=13, score=0.813, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=3 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=3, score=0.766, total=   0.2s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=3 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=3, score=0.840, total=   0.1s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=3 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=3, score=0.787, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=5 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=5, score=0.792, total=   0.1s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=5 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=5, score=0.813, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=5 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=5, score=0.787, total=   0.1s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=7 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=7, score=0.857, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=7 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=7, score=0.840, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=7 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=7, score=0.747, total=   0.1s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=9 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=9, score=0.857, total=   0.1s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=9 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=9, score=0.867, total=   0.1s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=9 ....................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=9, score=0.760, total=   0.2s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=10 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=10, score=0.870, total=   0.1s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=10 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=10, score=0.840, total=   0.1s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=10 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=10, score=0.773, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=11 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=11, score=0.805, total=   0.1s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=11 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=11, score=0.840, total=   0.2s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=11 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=11, score=0.787, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=12 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=12, score=0.857, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=12 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=12, score=0.787, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=12 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=12, score=0.787, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=13 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=13, score=0.831, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=13 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=13, score=0.880, total=   0.0s
# [CV] algorithm=brute, leaf_size=32, n_neighbors=13 ...................
# [CV]  algorithm=brute, leaf_size=32, n_neighbors=13, score=0.813, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=3 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=3, score=0.766, total=   0.1s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=3 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=3, score=0.840, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=3 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=3, score=0.787, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=5 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=5, score=0.792, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=5 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=5, score=0.813, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=5 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=5, score=0.787, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=7 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=7, score=0.857, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=7 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=7, score=0.840, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=7 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=7, score=0.747, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=9 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=9, score=0.857, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=9 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=9, score=0.867, total=   0.1s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=9 ....................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=9, score=0.760, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=10 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=10, score=0.870, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=10 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=10, score=0.840, total=   0.2s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=10 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=10, score=0.773, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=11 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=11, score=0.805, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=11 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=11, score=0.840, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=11 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=11, score=0.787, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=12 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=12, score=0.857, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=12 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=12, score=0.787, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=12 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=12, score=0.787, total=   0.2s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=13 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=13, score=0.831, total=   0.0s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=13 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=13, score=0.880, total=   0.1s
# [CV] algorithm=brute, leaf_size=34, n_neighbors=13 ...................
# [CV]  algorithm=brute, leaf_size=34, n_neighbors=13, score=0.813, total=   0.0s
# [Parallel(n_jobs=1)]: Done 576 out of 576 | elapsed:   21.9s finished
# D:\anaconda\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=KNeighborsClassifier(algorithm='auto', leaf_size=30,
#                                             metric='minkowski',
#                                             metric_params=None, n_jobs=None,
#                                             n_neighbors=5, p=2,
#                                             weights='uniform'),
#              iid='warn', n_jobs=None,
#              param_grid={'algorithm': ['ball_tree', 'kd_tree', 'brute'],
#                          'leaf_size': [18, 19, 20, 25, 27, 30, 32, 34],
#                          'n_neighbors': [3, 5, 7, 9, 10, 11, 12, 13]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
# let's see the  best parameters according to gridsearch
gridsearch.best_params_
# Out:
# {'algorithm': 'ball_tree', 'leaf_size': 18, 'n_neighbors': 13}

# %%
# we will use the best parameters in our k-NN algorithm and check if accuracy is increasing.
knn = KNeighborsClassifier(algorithm = 'ball_tree', leaf_size =18, n_neighbors =13)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='ball_tree', leaf_size=18, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=13, p=2,
#                      weights='uniform')

# %%
knn.score(x_train,y_train)
# Out:
# 0.8458149779735683

# %%
knn.score(x_test,y_test)
# Out:
# 0.8157894736842105

# %%
y_pred = knn.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8157894736842105

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8157894736842105

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: target, Length: 303, dtype: int64

# %%
#k-fold cross validation 
kfold = KFold(n_splits=12,random_state= 42)
kfold.get_n_splits(X_scaled)
# Out:
# 12

# %%
from statistics import mean
knn = KNeighborsClassifier(algorithm = 'ball_tree', leaf_size =18, n_neighbors =11)
cnt =0
count=[]
train_score =[]
test_score = []

for train_index,test_index in kfold.split(X_scaled):
    X_train, X_test = X_scaled[train_index], X_scaled[test_index] # our scaled data is an array so it can work on x[value]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index] # y is a dataframe so we have to use "iloc" to retreive data
    knn.fit(X_train,y_train)
    train_score_ = knn.score(X_train,y_train)
    test_score_ =  knn.score(X_test,y_test)
    cnt+=1
    count.append(cnt)
    train_score.append(train_score_)
    test_score.append(test_score_)
    
    print("for k = ", cnt)
    print("train_score is :  ", train_score_, "and test score is :  ", test_score_)
print("************************************************")
print("************************************************")
print("Average train score is :  ", mean(train_score))
print("Average test score is :  ", mean(test_score))
# Out:
# for k =  1
# train_score is :   0.855595667870036 and test score is :   0.9615384615384616
# for k =  2
# train_score is :   0.8483754512635379 and test score is :   0.8846153846153846
# for k =  3
# train_score is :   0.8411552346570397 and test score is :   0.9230769230769231
# for k =  4
# train_score is :   0.8597122302158273 and test score is :   0.72
# for k =  5
# train_score is :   0.8525179856115108 and test score is :   0.84
# for k =  6
# train_score is :   0.8669064748201439 and test score is :   0.84
# for k =  7
# train_score is :   0.8561151079136691 and test score is :   0.8
# for k =  8
# train_score is :   0.8633093525179856 and test score is :   0.72
# for k =  9
# train_score is :   0.8489208633093526 and test score is :   0.84
# for k =  10
# train_score is :   0.8525179856115108 and test score is :   0.68
# for k =  11
# train_score is :   0.8741007194244604 and test score is :   0.64
# for k =  12
# train_score is :   0.8741007194244604 and test score is :   0.52
# ************************************************
# ************************************************
# Average train score is :   0.8577773160532945
# Average test score is :   0.7807692307692308

# %%
# let's plot the test_accuracy with the value of k in k-fold

plt.plot(count,test_score)
plt.xlabel('Value of K for k-fold')
plt.ylabel('test accuracy')
plt.xticks(np.arange(0, 14, 1)) 
plt.yticks(np.arange(0.65, 1, 0.05))
# Out:
# ([<matplotlib.axis.YTick at 0xf426758908>,
#   <matplotlib.axis.YTick at 0xf432e8a888>,
#   <matplotlib.axis.YTick at 0xf432ea7708>,
#   <matplotlib.axis.YTick at 0xf4332d3648>,
#   <matplotlib.axis.YTick at 0xf4332d82c8>,
#   <matplotlib.axis.YTick at 0xf4332d8bc8>,
#   <matplotlib.axis.YTick at 0xf4332dd708>],
#  <a list of 7 Text yticklabel objects>)
